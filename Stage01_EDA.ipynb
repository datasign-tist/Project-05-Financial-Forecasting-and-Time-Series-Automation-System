# %%
import pandas as pd

# %%
payment = pd.read_csv('/Users/abhisheksharma/Desktop/Data_Sources/Raw_PaymentHistory_Data.csv')
payment
# Out:
#          LoanID  CustomerID ContactID  LoanAmountAsked  LoanAmountDisbursed  \
# 0        LN1000           1   CNT0001            26821                26026
# 1        LN1001           1   CNT0001            45580                44789
# 2        LN1002           1   CNT0001            22846                22072
# 3        LN1002           1   CNT0001            22846                22072
# 4        LN1002           1   CNT0001            22846                22072
# ...         ...         ...       ...              ...                  ...
# 176264  LN20899       10000  CNT10000            30714                29757
# 176265  LN20899       10000  CNT10000            30714                29757
# 176266  LN20899       10000  CNT10000            30714                29757
# 176267  LN20899       10000  CNT10000            30714                29757
# 176268  LN20899       10000  CNT10000            30714                29757
#
# ...

# %%
## Use the above data, Modify it in such a way that it can be used in default model

# %%
macro = pd.read_csv('/Users/abhisheksharma/Desktop/Data_Sources/Macroeconomic_Factors.csv')
macro
# Out:
#            Date  GDP_Growth (%)  Inflation_Rate (%)  Unemployment_Rate (%)  \
# 0    2020-01-01        2.000000            1.500000               3.500000
# 1    2020-02-01       -1.333333            1.695652               7.000000
# 2    2020-03-01       -4.666667            1.891304              10.500000
# 3    2020-04-01       -8.000000            2.086957              14.000000
# 4    2020-05-01       -8.000000            2.282609              14.000000
# ..          ...             ...                 ...                    ...
# 127  2030-08-01        2.164376            2.255257               3.692684
# 128  2030-09-01        1.735120            2.476869               3.924230
# 129  2030-10-01        2.256634            2.602346               3.625665
# 130  2030-11-01        2.048539            2.583007               4.489723
# 131  2030-12-01        2.484322            2.748155               3.570958
#
# ...
